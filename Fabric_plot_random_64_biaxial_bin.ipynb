# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhujajakkula/Fabric-plot/blob/main/Fabric_plot_random_64_biaxial_bin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.precision', 11)
df = pd.read_table(r"b64S100P.txt", delimiter=' ', names=['x_coord','y_coord','z_coord', 'a', 'b', 'c', 'radius', 'no'])
df
# Out:
#          x_coord        y_coord        z_coord           a           b  \
# 0           Time  Fragment:100;  LENGTH_SCALE:   0.015992;  Potential:
# 1     0.93738932     0.78518238     0.94434192  0.03126529  0.00009285
# 2     0.60232935     0.23285579     0.13542091  0.03126529  0.00026533
# 3     0.84747060     0.50075702     0.93258605  0.03126529  0.00006491
# 4     0.85132247     0.91717374     0.35632276  0.03126529  0.00011030
# ...          ...            ...            ...         ...         ...
# 4996  0.23813298     0.65478443     0.59034106  0.03126529  0.00008618
# 4997  0.60334112     0.48747776     0.34816500  0.03126529  0.00013812
# 4998  0.22171603     0.91216281     0.96156992  0.03126529  0.00004250
# 4999  0.46011653     0.49217171     0.45918811  0.03126529  0.00016704
# 5000  0.63737589     0.72846753     0.80270370  0.03126529  0.00009204
#
#                c      radius      no
# 0     0.59660000         NaN     NaN
# 1     0.00000310  1.00000000     0.0
# 2     0.00000356  1.00000000     1.0
# 3     0.00000110  1.00000000     2.0
# 4     0.00000361  1.00000000     3.0
# ...          ...         ...     ...
# 4996  0.00002308  0.99999884  4995.0
# 4997  0.00003088  0.99999997  4996.0
# 4998  0.00002239  0.98880476  4997.0
# 4999  0.00003949  0.99999990  4998.0
# 5000  0.00002202  0.99999988  4999.0
#
# [5001 rows x 8 columns]

# %%
df = df.drop(index=0)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#          x_coord     y_coord     z_coord           a           b           c  \
# 0     0.93738932  0.78518238  0.94434192  0.03126529  0.00009285  0.00000310
# 1     0.60232935  0.23285579  0.13542091  0.03126529  0.00026533  0.00000356
# 2     0.84747060  0.50075702  0.93258605  0.03126529  0.00006491  0.00000110
# 3     0.85132247  0.91717374  0.35632276  0.03126529  0.00011030  0.00000361
# 4     0.05654636  0.17362622  0.18331431  0.03126529  0.00011027  0.00000250
# ...          ...         ...         ...         ...         ...         ...
# 4995  0.23813298  0.65478443  0.59034106  0.03126529  0.00008618  0.00002308
# 4996  0.60334112  0.48747776  0.34816500  0.03126529  0.00013812  0.00003088
# 4997  0.22171603  0.91216281  0.96156992  0.03126529  0.00004250  0.00002239
# 4998  0.46011653  0.49217171  0.45918811  0.03126529  0.00016704  0.00003949
# 4999  0.63737589  0.72846753  0.80270370  0.03126529  0.00009204  0.00002202
#
#           radius      no
# 0     1.00000000     0.0
# 1     1.00000000     1.0
# 2     1.00000000     2.0
# 3     1.00000000     3.0
# 4     1.00000000     4.0
# ...          ...     ...
# 4995  0.99999884  4995.0
# 4996  0.99999997  4996.0
# 4997  0.98880476  4997.0
# 4998  0.99999990  4998.0
# 4999  0.99999988  4999.0
#
# [5000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 1 to 5000
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x_coord  5000 non-null   object
#  1   y_coord  5000 non-null   object
#  2   z_coord  5000 non-null   object
#  3   a        5000 non-null   object
#  4   b        5000 non-null   object
#  5   c        5000 non-null   float64
#  6   radius   5000 non-null   float64
#  7   no       5000 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 312.6+ KB

# %%
df[['x_coord', 'y_coord', 'z_coord']] = df[['x_coord', 'y_coord', 'z_coord']].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 1 to 5000
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x_coord  5000 non-null   float64
#  1   y_coord  5000 non-null   float64
#  2   z_coord  5000 non-null   float64
#  3   a        5000 non-null   object
#  4   b        5000 non-null   object
#  5   c        5000 non-null   float64
#  6   radius   5000 non-null   float64
#  7   no       5000 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 312.6+ KB

# %%
import plotly.express as px
import plotly.graph_objects as go

# Create a Plotly figure
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=df.x_coord, y=df.y_coord, z=df.z_coord, mode='markers', marker=dict(size=4, opacity=0.5, line=dict(width=2, color='black'))))
fig.show()
fig.write_html("scatter_plot_random_64.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7e397a84-fab7-446b-9556-09cb78661e6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e397a84-fab7-446b-9556-09cb78661e6d")) {                    Plotly.newPlot(                        "7e397a84-fab7-446b-9556-09cb78661e6d",                        [{"marker":{"line":{"color":"black","width":2},"opacity":0.5,"size":4},"mode":"markers","x":[0.93684891,0.60230592,0.84760403,0.85034819,0.05624228,0.02112426,0.40725562,0.58871856,0.46090015,0.90932613,0.58058432,0.53589048,0.73002466,0.58568072,0.01067536,0.23790854,0.79900422,0.55682596,0.80982003,0.1980355,0.62339742,0.91619588,0.26083838,0.280677,0.2102473,0.19933148,0.52711708,0.66792945,0.15843042,0.97806532,0.13662948,0.67407219,0.06268284,0.38891903,0.38544992,0.1378908,0.4311164,0.93990759,0.13922637,0.53499824,0.17588836,0.5205438,0.14737764,0.6757862,0.70119284,0.56528327,0.36362939,0.87617638,0.4924362,0.14687126,0.22169017,0.0231802,0.61802109,0.26164381,0.23032623,0.60833689,0.62554215,0.77751798,0.76358464,0.75728385,0.60830925,0.51049121,0.08485323,0.56844899,0.17614732,0.46719756,0.31185872,0.25704655,0.14387338,0.9730717,0.51169446,0.01183131,0.75121658,0.11410416,0.56142479,0.98374782,0.72846991,0.42166083,0.64523738,0.04622794,0.59262154,0.85367673,0.3680089,0.09249672,0.08975454,0.72081206,0.66279454,0.47026807,0.93128578,0.92379485,0.08477223,0.91127672,0.22503017,0.9237334,0.42438846,0.27418096,0.73246303,0.29131998,0.07153159,0.43614886,0.97773739,0.54835526,0.93108457,0.9812168,0.79759571,0.93934912,0.40948563,0.84262987,0.70225533,0.50291054,0.17712058,0.77424621,0.69706806,0.45849038,0.91775154,0.29569835,0.19377288,0.37207439,0.23378275,0.6944311,0.8250045,0.66288172,0.17194357,0.62102848,0.76823622,0.18070867,0.99884302,0.21336459,0.69846152,0.0549469,0.19031602,0.44331444,0.14992906,0.38948249,0.84959003,0.63462607,0.51968838,0.95599601,0.90722806,0.98630073,0.53709463,0.16726508,0.58103833,0.33369024,0.89029444,0.61413154,0.29224344,0.42561762,0.29455321,0.02372152,0.53082607,0.48672877,0.65477346,0.19969633,0.68964342,0.95481854,0.21439269,0.38105141,0.66901563,0.08478291,0.20122517,0.47332097,0.31658567,0.74006724,0.08410908,0.52321588,0.48343628,0.38005207,0.31828856,0.02544093,0.62493474,0.53186535,0.08447703,0.46815456,0.24606791,0.44096661,0.59998002,0.13951398,0.2453487,0.39437507,0.62560413,0.5303227,0.44505157,0.16727734,0.84553356,0.38078982,0.49884082,0.52884101,0.89505615,0.16383641,0.60252779,0.18733435,0.56777909,0.84853483,0.79597311,0.68915816,0.12091454,0.22919293,0.85234944,0.93797861,0.78068657,0.84533516,0.61203258,0.27985624,0.1502631,0.61016407,0.18690641,0.15392002,0.8203931,0.19924854,0.78718869,0.07736419,0.55280452,0.74603602,0.69287238,0.38249613,0.00114559,0.40490181,0.75655957,0.19877843,0.86939722,0.26710901,0.76724402,0.8618845,0.23431692,0.80757797,0.3171326,0.52420634,0.01081976,0.37589683,0.64359695,0.62255337,0.87499406,0.51277593,0.44911713,0.88783285,0.47745766,0.52539998,0.02046529,0.06348547,0.36857787,0.15260104,0.39117368,0.54626596,0.38862306,0.61957596,0.58156309,0.42411474,0.50217939,0.58628108,0.85186528,0.18911481,0.81826215,0.51635288,0.09571916,0.92961309,0.63145272,0.62780263,0.53169523,0.2421284,0.13120501,0.80245541,0.99055279,0.69605526,0.38994864,0.65481434,0.19514572,0.67481422,0.54140925,0.79488499,0.40878159,0.80318109,0.16470665,0.81291771,0.37816394,0.05931306,0.65371031,0.64982616,0.32695147,0.40162982,0.25689405,0.91562188,0.42700737,0.66601564,0.24147859,0.17463966,0.48365753,0.75251858,0.7060053,0.68744396,0.05621781,0.19861688,0.31408987,0.95741379,0.61012881,0.6823668,0.94479941,0.45366911,0.08598129,0.30118948,0.72227801,0.95594801,0.72359191,0.26298203,0.31806403,0.22401734,0.26378623,0.1867016 ...

# %%
df['x_coord'].describe()
# Out:
# count    5000.00000000000
# mean        0.49982413527
# std         0.28823668196
# min         0.00034145000
# 25%         0.24938498250
# 50%         0.50011061000
# 75%         0.75021620500
# max         0.99967492000
# Name: x_coord, dtype: float64

# %%
df['x_coord'].hist()
# Out:
# <Axes: >

# %%
'''
ff_file = open("FF.txt")
s = ff_file.readlines()
s[2029]
for i in range(len(s)):
    if len(s[i])>=10:
        print(i)
        
ff_dic={}
for i in range(1,len(s)):
    if len(s[i])>=10:
        ff_dic[i]= list(map(float, s[i][:-1].split('\t')))

        
force = pd.read_table(r"C:/Users/sindh/FYP/FF.txt", sep='\t ', names=['p1','p2','f','f1', 'f2'])
force
'''
# Out:
# '\nff_file = open("FF.txt")\ns = ff_file.readlines()\ns[2029]\nfor i in range(len(s)):\n    if len(s[i])>=10:\n        print(i)\n        \nff_dic={}\nfor i in range(1,len(s)):\n    if len(s[i])>=10:\n        ff_dic[i]= list(map(float, s[i][:-1].split(\'\t\')))\n\n        \nforce = pd.read_table(r"C:/Users/sindh/FYP/FF.txt", sep=\'\t \', names=[\'p1\',\'p2\',\'f\',\'f1\', \'f2\'])\nforce\n'

# %%
force = pd.read_csv(r"b64S100C.txt", sep=" ", header=None)
force.columns = ["p1", "p2", "f", "f1"]

# %%
force
# Out:
#          p1    p2            f          f1
# 0         0  1409   8.44958333  0.61456321
# 1         0  1183   4.46191635  0.25581465
# 2         0  1244  13.61894893  1.36176153
# 3         0  1609   3.32064002  0.33206400
# 4         0  3433  23.40348317  2.27529119
# ...     ...   ...          ...         ...
# 14746  4923  4988   9.18759808  0.91711685
# 14747  4945  4991  26.66280789  0.91445510
# 14748  4945  4963   7.26544304  0.72537252
# 14749  4946  4991   9.79259839  0.65434544
# 14750  4946  4963   5.13657757  0.51221276
#
# [14751 rows x 4 columns]

# %%
force['p2'].max()
# Out:
# 4999

# %%
df
# Out:
#          x_coord     y_coord     z_coord           a           b           c  \
# 0     0.93738932  0.78518238  0.94434192  0.03126529  0.00009285  0.00000310
# 1     0.60232935  0.23285579  0.13542091  0.03126529  0.00026533  0.00000356
# 2     0.84747060  0.50075702  0.93258605  0.03126529  0.00006491  0.00000110
# 3     0.85132247  0.91717374  0.35632276  0.03126529  0.00011030  0.00000361
# 4     0.05654636  0.17362622  0.18331431  0.03126529  0.00011027  0.00000250
# ...          ...         ...         ...         ...         ...         ...
# 4995  0.23813298  0.65478443  0.59034106  0.03126529  0.00008618  0.00002308
# 4996  0.60334112  0.48747776  0.34816500  0.03126529  0.00013812  0.00003088
# 4997  0.22171603  0.91216281  0.96156992  0.03126529  0.00004250  0.00002239
# 4998  0.46011653  0.49217171  0.45918811  0.03126529  0.00016704  0.00003949
# 4999  0.63737589  0.72846753  0.80270370  0.03126529  0.00009204  0.00002202
#
#           radius      no
# 0     1.00000000     0.0
# 1     1.00000000     1.0
# 2     1.00000000     2.0
# 3     1.00000000     3.0
# 4     1.00000000     4.0
# ...          ...     ...
# 4995  0.99999884  4995.0
# 4996  0.99999997  4996.0
# 4997  0.98880476  4997.0
# 4998  0.99999990  4998.0
# 4999  0.99999988  4999.0
#
# [5000 rows x 8 columns]

# %%
force['xp1']=np.array(df['x_coord'][force['p1']])
force['yp1']=np.array(df['y_coord'][force['p1']])
force['zp1']=np.array(df['z_coord'][force['p1']])
force['xp2']=np.array(df['x_coord'][force['p2']])
force['yp2']=np.array(df['y_coord'][force['p2']])
force['zp2']=np.array(df['z_coord'][force['p2']])

# %%
force
# Out:
#          p1    p2            f          f1         xp1         yp1  \
# 0         0  1409   8.44958333  0.61456321  0.93738932  0.78518238
# 1         0  1183   4.46191635  0.25581465  0.93738932  0.78518238
# 2         0  1244  13.61894893  1.36176153  0.93738932  0.78518238
# 3         0  1609   3.32064002  0.33206400  0.93738932  0.78518238
# 4         0  3433  23.40348317  2.27529119  0.93738932  0.78518238
# ...     ...   ...          ...         ...         ...         ...
# 14746  4923  4988   9.18759808  0.91711685  0.54797666  0.45521099
# 14747  4945  4991  26.66280789  0.91445510  0.99216048  0.66326779
# 14748  4945  4963   7.26544304  0.72537252  0.99216048  0.66326779
# 14749  4946  4991   9.79259839  0.65434544  0.93283438  0.64355461
# 14750  4946  4963   5.13657757  0.51221276  0.93283438  0.64355461
#
#               zp1         xp2         yp2         zp2
# 0      0.94434192  0.90242387  0.73811813  0.92335794
# 1      0.94434192  0.95681615  0.84443224  0.94540326
# 2      0.94434192  0.98714180  0.75790577  0.96977084
# 3      0.94434192  0.87609517  0.79314969  0.93583474
# 4      0.94434192  0.90659026  0.82715021  0.97806092
# ...           ...         ...         ...         ...
# 14746  0.18203835  0.51338251  0.49671777  0.21296642
# 14747  0.74323910  0.97486576  0.60558872  0.72857102
# 14748  0.74323910  0.94365125  0.69236004  0.71713318
# 14749  0.75438954  0.97486576  0.60558872  0.72857102
# 14750  0.75438954  0.94365125  0.69236004  0.71713318
#
# [14751 rows x 10 columns]

# %%
force['vector_xcomp']=force['xp2']-force['xp1']
force['vector_ycomp']=force['yp2']-force['yp1']
force['vector_zcomp']=force['zp2']-force['zp1']

# %%
force
# Out:
#          p1    p2            f          f1         xp1         yp1  \
# 0         0  1409   8.44958333  0.61456321  0.93738932  0.78518238
# 1         0  1183   4.46191635  0.25581465  0.93738932  0.78518238
# 2         0  1244  13.61894893  1.36176153  0.93738932  0.78518238
# 3         0  1609   3.32064002  0.33206400  0.93738932  0.78518238
# 4         0  3433  23.40348317  2.27529119  0.93738932  0.78518238
# ...     ...   ...          ...         ...         ...         ...
# 14746  4923  4988   9.18759808  0.91711685  0.54797666  0.45521099
# 14747  4945  4991  26.66280789  0.91445510  0.99216048  0.66326779
# 14748  4945  4963   7.26544304  0.72537252  0.99216048  0.66326779
# 14749  4946  4991   9.79259839  0.65434544  0.93283438  0.64355461
# 14750  4946  4963   5.13657757  0.51221276  0.93283438  0.64355461
#
#               zp1         xp2         yp2         zp2  vector_xcomp  \
# 0      0.94434192  0.90242387  0.73811813  0.92335794   -0.03496545
# 1      0.94434192  0.95681615  0.84443224  0.94540326    0.01942683
# 2      0.94434192  0.98714180  0.75790577  0.96977084    0.04975248
# 3      0.94434192  0.87609517  0.79314969  0.93583474   -0.06129415
# 4      0.94434192  0.90659026  0.82715021  0.97806092   -0.03079906
# ...           ...         ...         ...         ...           ...
# 14746  0.18203835  0.51338251  0.49671777  0.21296642   -0.03459415
# 14747  0.74323910  0.97486576  0.60558872  0.72857102   -0.01729472
# 14748  0.74323910  0.94365125  0.69236004  0.71713318   -0.04850923
# 14749  0.75438954  0.97486576  0.60558872  0.72857102    0.04203138
# 14750  0.75438954  0.94365125  0.69236004  0.71713318    0.01081687
#
#        vector_ycomp  vector_zcomp
# 0       -0.04706425   -0.02098398
# 1        0.05924986    0.00106134
# 2       -0.02727661    0.02542892
# 3        0.00796731   -0.00850718
# 4        0.04196783    0.03371900
# ...             ...           ...
# 14746    0.04150678    0.03092807
# 14747   -0.05767907   -0.01466808
# 14748    0.02909225   -0.02610592
# 14749   -0.03796589   -0.02581852
# 14750    0.04880543   -0.03725636
#
# [14751 rows x 13 columns]

# %%
vector_array = force[['vector_xcomp', 'vector_ycomp', 'vector_zcomp']].to_numpy()

# %%
vector_array
# Out:
# array([[-0.03496545, -0.04706425, -0.02098398],
#        [ 0.01942683,  0.05924986,  0.00106134],
#        [ 0.04975248, -0.02727661,  0.02542892],
#        ...,
#        [-0.04850923,  0.02909225, -0.02610592],
#        [ 0.04203138, -0.03796589, -0.02581852],
#        [ 0.01081687,  0.04880543, -0.03725636]])

# %%
import numpy as np
import math

def CartesianToSpherical(vector_array):
    '''
    func CartesianToSpherical - changes cartesian coordinates to spherical coordinates
    input - array, 3 columns - x, y, z components of vectors, rows - number of vectors
    output - array, 3 columns - r, phi, theta
    
    '''
    ptsnew = np.zeros(vector_array.shape)
    xy = vector_array[:,0]**2 + vector_array[:,1]**2
    ptsnew[:,0] = np.sqrt(xy + vector_array[:,2]**2)
    ptsnew[:,1] = np.degrees(np.arctan2(np.sqrt(xy), vector_array[:,2])) # for elevation angle defined from Z-axis down
    #ptsnew[:,4] = np.arctan2(xyz[:,2], np.sqrt(xy)) # for elevation angle defined from XY-plane up
    ptsnew[:,2] = np.degrees(np.arctan2(vector_array[:,1], vector_array[:,0]))
    return ptsnew

# %%
SphericalCoordArray_deg = CartesianToSpherical(vector_array)

# %%
SphericalCoordArray_deg
# Out:
# array([[ 6.22732185e-02,  1.09692156e+02, -1.26609770e+02],
#        [ 6.23624412e-02,  8.90248419e+01,  7.18467297e+01],
#        [ 6.21767858e-02,  6.58593672e+01, -2.87335902e+01],
#        ...,
#        [ 6.22978608e-02,  1.14774626e+02,  1.49047785e+02],
#        [ 6.22466199e-02,  1.14505328e+02, -4.20907108e+01],
#        [ 6.23458983e-02,  1.26696428e+02,  7.75033943e+01]])

# %%
spher_df = pd.DataFrame(SphericalCoordArray_deg, columns = ['r', 'phi', 'theta'])

#convert array containing spherical coordinates of vector into a dataframe

# %%
spher_df
# Out:
#                    r              phi            theta
# 0      0.06227321847  109.69215596578 -126.60976998982
# 1      0.06236244123   89.02484191840   71.84672971219
# 2      0.06217678579   65.85936715780  -28.73359024356
# 3      0.06239249125   97.83665755106  172.59394229975
# 4      0.06202299423   57.06732321133  126.27394229519
# ...              ...              ...              ...
# 14746  0.06225844131   60.21352525210  129.80977990993
# 14747  0.06197689107  103.69009276957 -106.69104095849
# 14748  0.06229786083  114.77462597666  149.04778521212
# 14749  0.06224661985  114.50532827782  -42.09071079500
# 14750  0.06234589830  126.69642778560   77.50339425266
#
# [14751 rows x 3 columns]

# %%
#spher_df.index += 1
#changing index to start from 1

# %%
force = pd.concat([force, spher_df], axis=1, join='inner')
#concatenating force and spherical coordinates df to force dataframe

# %%
force
# Out:
#          p1    p2            f          f1         xp1         yp1  \
# 0         0  1409   8.44958333  0.61456321  0.93738932  0.78518238
# 1         0  1183   4.46191635  0.25581465  0.93738932  0.78518238
# 2         0  1244  13.61894893  1.36176153  0.93738932  0.78518238
# 3         0  1609   3.32064002  0.33206400  0.93738932  0.78518238
# 4         0  3433  23.40348317  2.27529119  0.93738932  0.78518238
# ...     ...   ...          ...         ...         ...         ...
# 14746  4923  4988   9.18759808  0.91711685  0.54797666  0.45521099
# 14747  4945  4991  26.66280789  0.91445510  0.99216048  0.66326779
# 14748  4945  4963   7.26544304  0.72537252  0.99216048  0.66326779
# 14749  4946  4991   9.79259839  0.65434544  0.93283438  0.64355461
# 14750  4946  4963   5.13657757  0.51221276  0.93283438  0.64355461
#
#               zp1         xp2         yp2         zp2  vector_xcomp  \
# 0      0.94434192  0.90242387  0.73811813  0.92335794   -0.03496545
# 1      0.94434192  0.95681615  0.84443224  0.94540326    0.01942683
# 2      0.94434192  0.98714180  0.75790577  0.96977084    0.04975248
# 3      0.94434192  0.87609517  0.79314969  0.93583474   -0.06129415
# 4      0.94434192  0.90659026  0.82715021  0.97806092   -0.03079906
# ...           ...         ...         ...         ...           ...
# 14746  0.18203835  0.51338251  0.49671777  0.21296642   -0.03459415
# 14747  0.74323910  0.97486576  0.60558872  0.72857102   -0.01729472
# 14748  0.74323910  0.94365125  0.69236004  0.71713318   -0.04850923
# 14749  0.75438954  0.97486576  0.60558872  0.72857102    0.04203138
# 14750  0.75438954  0.94365125  0.69236004  0.71713318    0.01081687
#
#        vector_ycomp  vector_zcomp              r              phi  \
# 0       -0.04706425   -0.02098398  0.06227321847  109.69215596578
# 1        0.05924986    0.00106134  0.06236244123   89.02484191840
# 2       -0.02727661    0.02542892  0.06217678579   65.85936715780
# 3        0.00796731   -0.00850718  0.06239249125   97.83665755106
# 4        0.04196783    0.03371900  0.06202299423   57.06732321133
# ...             ...           ...            ...              ...
# 14746    0.04150678    0.03092807  0.06225844131   60.21352525210
# 14747   -0.05767907   -0.01466808  0.06197689107  103.69009276957
# 14748    0.02909225   -0.02610592  0.06229786083  114.77462597666
# 14749   -0.03796589   -0.02581852  0.06224661985  114.50532827782
# 14750    0.04880543   -0.03725636  0.06234589830  126.69642778560
#
#                  theta
# 0     -126.60976998982
# 1       71.84672971219
# 2      -28.73359024356
# 3      172.59394229975
# 4      126.27394229519
# ...                ...
# 14746  129.80977990993
# 14747 -106.69104095849
# 14748  149.04778521212
# 14749  -42.09071079500
# 14750   77.50339425266
#
# [14751 rows x 16 columns]

# %%
force.columns
#displaying columns in force dataframe
# Out:
# Index(['p1', 'p2', 'f', 'f1', 'xp1', 'yp1', 'zp1', 'xp2', 'yp2', 'zp2',
#        'vector_xcomp', 'vector_ycomp', 'vector_zcomp', 'r', 'phi', 'theta'],
#       dtype='object')

# %%
force['theta'].describe()
#angle on the xy plane
#output shows that theta ranges from -179 to 180 degrees
# Out:
# count    14751.00000000000
# mean        -0.17249247174
# std        103.61113887583
# min       -179.93924334730
# 25%        -90.76689304192
# 50%         -0.04561455953
# 75%         88.24225826948
# max        179.91408037050
# Name: theta, dtype: float64

# %%
force['phi'].describe()
#azimuthal angle, measured from positive z aixs
#output shows that phi ranges from 45 to 90
# Out:
# count    14751.00000000000
# mean        89.94143233623
# std         39.80551779650
# min          0.21829915867
# 25%         59.18114039095
# 50%         89.90764406234
# 75%        121.17554395365
# max        179.19029543595
# Name: phi, dtype: float64

# %% [markdown]
# In the above code, we have considered force acting only one particle in contact. Since conntact force acts on both the particles. We will apply same amount of force on the other particle in contact.
#
#
# Following similar code again to generate another half of force vectors.
# The dataframe is named as force2

# %%
force2 = pd.read_csv(r"b64S100C.txt", sep=" ", header=None)
force2.columns = ["p2", "p1", "f", "f1"]
force2['xp1']=np.array(df['x_coord'][force2['p1']])
force2['yp1']=np.array(df['y_coord'][force2['p1']])
force2['zp1']=np.array(df['z_coord'][force2['p1']])
force2['xp2']=np.array(df['x_coord'][force2['p2']])
force2['yp2']=np.array(df['y_coord'][force2['p2']])
force2['zp2']=np.array(df['z_coord'][force2['p2']])

force2['vector_xcomp']=force2['xp2']-force2['xp1']
force2['vector_ycomp']=force2['yp2']-force2['yp1']
force2['vector_zcomp']=force2['zp2']-force2['zp1']

vector_array = force2[['vector_xcomp', 'vector_ycomp', 'vector_zcomp']].to_numpy()

SphericalCoordArray_deg2 = CartesianToSpherical(vector_array)
spher_df2 = pd.DataFrame(SphericalCoordArray_deg2, columns = ['r', 'phi', 'theta'])
force2 = pd.concat([force2, spher_df2], axis=1, join='inner')

# %%
force2
# Out:
#          p2    p1            f          f1         xp1         yp1  \
# 0         0  1409   8.44958333  0.61456321  0.90242387  0.73811813
# 1         0  1183   4.46191635  0.25581465  0.95681615  0.84443224
# 2         0  1244  13.61894893  1.36176153  0.98714180  0.75790577
# 3         0  1609   3.32064002  0.33206400  0.87609517  0.79314969
# 4         0  3433  23.40348317  2.27529119  0.90659026  0.82715021
# ...     ...   ...          ...         ...         ...         ...
# 14746  4923  4988   9.18759808  0.91711685  0.51338251  0.49671777
# 14747  4945  4991  26.66280789  0.91445510  0.97486576  0.60558872
# 14748  4945  4963   7.26544304  0.72537252  0.94365125  0.69236004
# 14749  4946  4991   9.79259839  0.65434544  0.97486576  0.60558872
# 14750  4946  4963   5.13657757  0.51221276  0.94365125  0.69236004
#
#               zp1         xp2         yp2         zp2  vector_xcomp  \
# 0      0.92335794  0.93738932  0.78518238  0.94434192    0.03496545
# 1      0.94540326  0.93738932  0.78518238  0.94434192   -0.01942683
# 2      0.96977084  0.93738932  0.78518238  0.94434192   -0.04975248
# 3      0.93583474  0.93738932  0.78518238  0.94434192    0.06129415
# 4      0.97806092  0.93738932  0.78518238  0.94434192    0.03079906
# ...           ...         ...         ...         ...           ...
# 14746  0.21296642  0.54797666  0.45521099  0.18203835    0.03459415
# 14747  0.72857102  0.99216048  0.66326779  0.74323910    0.01729472
# 14748  0.71713318  0.99216048  0.66326779  0.74323910    0.04850923
# 14749  0.72857102  0.93283438  0.64355461  0.75438954   -0.04203138
# 14750  0.71713318  0.93283438  0.64355461  0.75438954   -0.01081687
#
#        vector_ycomp  vector_zcomp              r              phi  \
# 0        0.04706425    0.02098398  0.06227321847   70.30784403422
# 1       -0.05924986   -0.00106134  0.06236244123   90.97515808160
# 2        0.02727661   -0.02542892  0.06217678579  114.14063284220
# 3       -0.00796731    0.00850718  0.06239249125   82.16334244894
# 4       -0.04196783   -0.03371900  0.06202299423  122.93267678867
# ...             ...           ...            ...              ...
# 14746   -0.04150678   -0.03092807  0.06225844131  119.78647474790
# 14747    0.05767907    0.01466808  0.06197689107   76.30990723043
# 14748   -0.02909225    0.02610592  0.06229786083   65.22537402334
# 14749    0.03796589    0.02581852  0.06224661985   65.49467172218
# 14750   -0.04880543    0.03725636  0.06234589830   53.30357221440
#
#                  theta
# 0       53.39023001018
# 1     -108.15327028781
# 2      151.26640975644
# 3       -7.40605770025
# 4      -53.72605770481
# ...                ...
# 14746  -50.19022009007
# 14747   73.30895904151
# 14748  -30.95221478788
# 14749  137.90928920500
# 14750 -102.49660574734
#
# [14751 rows x 16 columns]

# %%
force['theta'].describe()
# Out:
# count    14751.00000000000
# mean        -0.17249247174
# std        103.61113887583
# min       -179.93924334730
# 25%        -90.76689304192
# 50%         -0.04561455953
# 75%         88.24225826948
# max        179.91408037050
# Name: theta, dtype: float64

# %%
force2['theta'].describe()
# Out:
# count    14751.00000000000
# mean        -0.13588478412
# std        103.28096267210
# min       -179.93512139978
# 25%        -91.66948932434
# 50%          0.10356589789
# 75%         89.26274133398
# max        179.98815613192
# Name: theta, dtype: float64

# %%
force['phi'].describe()
# Out:
# count    14751.00000000000
# mean        89.94143233623
# std         39.80551779650
# min          0.21829915867
# 25%         59.18114039095
# 50%         89.90764406234
# 75%        121.17554395365
# max        179.19029543595
# Name: phi, dtype: float64

# %%
force2['phi'].describe()
# Out:
# count    14751.00000000000
# mean        90.05856766377
# std         39.80551779650
# min          0.80970456405
# 25%         58.82445604635
# 50%         90.09235593766
# 75%        120.81885960905
# max        179.78170084133
# Name: phi, dtype: float64

# %% [markdown]
# phi - azimuthal angle measured from +ve z-axis.
#
# phi range is from 45 to 135 degreess.

# %%
force = pd.concat([force, force2])

# %%
force
# Out:
#          p1    p2            f          f1         xp1         yp1  \
# 0         0  1409   8.44958333  0.61456321  0.93738932  0.78518238
# 1         0  1183   4.46191635  0.25581465  0.93738932  0.78518238
# 2         0  1244  13.61894893  1.36176153  0.93738932  0.78518238
# 3         0  1609   3.32064002  0.33206400  0.93738932  0.78518238
# 4         0  3433  23.40348317  2.27529119  0.93738932  0.78518238
# ...     ...   ...          ...         ...         ...         ...
# 14746  4988  4923   9.18759808  0.91711685  0.51338251  0.49671777
# 14747  4991  4945  26.66280789  0.91445510  0.97486576  0.60558872
# 14748  4963  4945   7.26544304  0.72537252  0.94365125  0.69236004
# 14749  4991  4946   9.79259839  0.65434544  0.97486576  0.60558872
# 14750  4963  4946   5.13657757  0.51221276  0.94365125  0.69236004
#
#               zp1         xp2         yp2         zp2  vector_xcomp  \
# 0      0.94434192  0.90242387  0.73811813  0.92335794   -0.03496545
# 1      0.94434192  0.95681615  0.84443224  0.94540326    0.01942683
# 2      0.94434192  0.98714180  0.75790577  0.96977084    0.04975248
# 3      0.94434192  0.87609517  0.79314969  0.93583474   -0.06129415
# 4      0.94434192  0.90659026  0.82715021  0.97806092   -0.03079906
# ...           ...         ...         ...         ...           ...
# 14746  0.21296642  0.54797666  0.45521099  0.18203835    0.03459415
# 14747  0.72857102  0.99216048  0.66326779  0.74323910    0.01729472
# 14748  0.71713318  0.99216048  0.66326779  0.74323910    0.04850923
# 14749  0.72857102  0.93283438  0.64355461  0.75438954   -0.04203138
# 14750  0.71713318  0.93283438  0.64355461  0.75438954   -0.01081687
#
#        vector_ycomp  vector_zcomp              r              phi  \
# 0       -0.04706425   -0.02098398  0.06227321847  109.69215596578
# 1        0.05924986    0.00106134  0.06236244123   89.02484191840
# 2       -0.02727661    0.02542892  0.06217678579   65.85936715780
# 3        0.00796731   -0.00850718  0.06239249125   97.83665755106
# 4        0.04196783    0.03371900  0.06202299423   57.06732321133
# ...             ...           ...            ...              ...
# 14746   -0.04150678   -0.03092807  0.06225844131  119.78647474790
# 14747    0.05767907    0.01466808  0.06197689107   76.30990723043
# 14748   -0.02909225    0.02610592  0.06229786083   65.22537402334
# 14749    0.03796589    0.02581852  0.06224661985   65.49467172218
# 14750   -0.04880543    0.03725636  0.06234589830   53.30357221440
#
#                  theta
# 0     -126.60976998982
# 1       71.84672971219
# 2      -28.73359024356
# 3      172.59394229975
# 4      126.27394229519
# ...                ...
# 14746  -50.19022009007
# 14747   73.30895904151
# 14748  -30.95221478788
# 14749  137.90928920500
# 14750 -102.49660574734
#
# [29502 rows x 16 columns]

# %%
force = force.reset_index(drop=True)

# %%
longitude = np.array([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])

#longitude defined by theta angle, range - [-180,180] with 30 degrees gap

#we will take theta value of each force vector, compare it with the defined longitude values, take abs min value longitiude value for the force vector
longitude_column_list = [longitude[np.argmin(abs(i - longitude))] for i in force['theta']]
force['longitude']=longitude_column_list
#creating a longitude column in force dataframe, assigning abs min value longitiude value for the force vector.

# %%
force['longitude'] = force['longitude'].replace([-180], 180)
#replacing -180 with 180, as they both represent the same direction but measured from different orientation

# %%
lattitude = np.array([0, 30, 60, 90, 120, 150, 180])
#lattitude defined by phi angle, range - [0,180] with 30 degrees gap

lattitude_column_list = [lattitude[np.argmin(abs(i - lattitude))] for i in force['phi']]
#we will take phi value of each force vector, compare it with the defined latitude values, take abs difference value with each of the defined lattitude. lattitude with min abs difference value is considered for the force vector

force['lattitude']=lattitude_column_list
#creating a lattitude column in force dataframe, assigning min abs difference lattitude value for the force vector.

# %%
result = force.groupby(['longitude','lattitude']).agg({'r':['sum','count']})
print(result)
# Out:
#                                   r
#                                 sum count
# longitude lattitude
# -150      0           2.85662586343    46
#           30         17.40856794843   280
#           60         32.67852658037   525
#           90         40.47565192920   650
#           120        30.31314998878   487
# ...                             ...   ...
#  180      60         27.76671517567   446
#           90         35.95004461986   577
#           120        30.88797014563   496
#           150        20.96119672669   337
#           180         2.36130189985    38
#
# [84 rows x 2 columns]

# %%
result = result.reset_index()
result.columns = ['longitude', 'lattitude','r_sum','r_count']

# %%
result
# Out:
#     longitude  lattitude           r_sum  r_count
# 0        -150          0   2.85662586343       46
# 1        -150         30  17.40856794843      280
# 2        -150         60  32.67852658037      525
# 3        -150         90  40.47565192920      650
# 4        -150        120  30.31314998878      487
# ..        ...        ...             ...      ...
# 79        180         60  27.76671517567      446
# 80        180         90  35.95004461986      577
# 81        180        120  30.88797014563      496
# 82        180        150  20.96119672669      337
# 83        180        180   2.36130189985       38
#
# [84 rows x 4 columns]

# %%
def SphericalToCartesian(vector_array):
    '''
    vector array 1st element - theta
    2nd element - phi
    3rd element - r
    
    '''
    ptsnew = np.zeros(vector_array.shape)
    xy = vector_array[:,0]**2 + vector_array[:,1]**2
    ptsnew[:,0] = vector_array[:,2]*np.cos(vector_array[:,0] * np.pi / 180)*np.sin(vector_array[:,1] * np.pi / 180)
    ptsnew[:,1] = vector_array[:,2]*np.sin(vector_array[:,0] * np.pi / 180)*np.sin(vector_array[:,1] * np.pi / 180) # for elevation angle defined from Z-axis down
    ptsnew[:,2] = vector_array[:,2]*np.cos(vector_array[:,1] * np.pi / 180)
    return ptsnew

# %%
spherical_coord_count = result[['longitude','lattitude','r_count']].to_numpy()

# %%
spherical_coord_count
# Out:
# array([[-150,    0,   46],
#        [-150,   30,  280],
#        [-150,   60,  525],
#        [-150,   90,  650],
#        [-150,  120,  487],
#        [-150,  150,  354],
#        [-150,  180,   38],
#        [-120,    0,   50],
#        [-120,   30,  384],
#        [-120,   60,  539],
#        [-120,   90,  664],
#        [-120,  120,  571],
#        [-120,  150,  378],
#        [-120,  180,   45],
#        [ -90,    0,   45],
#        [ -90,   30,  370],
#        [ -90,   60,  549],
#        [ -90,   90,  651],
#        [ -90,  120,  562],
#        [ -90,  150,  301],
#        [ -90,  180,   37],
#        [ -60,    0,   40],
#        [ -60,   30,  308],
#        [ -60,   60,  565],
#        [ -60,   90,  661],
#        [ -60,  120,  556],
#        [ -60,  150,  317],
#        [ -60,  180,   36],
#        [ -30,    0,   47],
#        [ -30,   30,  303],
#        [ -30,   60,  600],
#        [ -30,   90,  546],
#        [ -30,  120,  572],
#        [ -30,  150,  365],
#        [ -30,  180,   27],
#        [   0,    0,   38],
#        [   0,   30,  337],
#        [   0,   60,  496],
#        [   0,   90,  577],
#        [   0,  120,  446],
#        [   0,  150,  345],
#        [   0,  180,   43],
#        [  30,    0,   38],
#        [  30,   30,  354],
#        [  30,   60,  487],
#        [  30,   90,  650],
#        [  30,  120,  525],
#        [  30,  150,  280],
#        [  30,  180,   46],
#        [  60,    0,   45],
#        [  60,   30,  378],
#        [  60,   60,  571],
#        [  60,   90,  664],
#        [  60,  120,  539],
#        [  60,  150,  384],
#        [  60,  180,   50],
#        [  90,    0,   37],
#        [  90,   30,  301],
#        [  90,   60,  562],
#        [  90,   90,  651],
#        [  90,  120,  549],
#        [  90,  150,  370],
#        [  90,  180,   45],
#        [ 120,    0,   36],
#        [ 120,   30,  317],
#        [ 120,   60,  556],
#        [ 120,   90,  661],
#        [ 120,  120,  565],
#        [ 120,  150,  308],
#        [ 120,  180,   40],
#        [ 150,    0,   27],
#        [ 150,   30,  365],
#        [ 150,   60,  572],
#        [ 150,   90,  546],
#        [ 150,  120,  600],
#        [ 150,  150,  303],
#        [ 150,  180,   47],
#        [ 180,    0,   43],
#        [ 180,   30,  345],
#        [ 180,   60,  446],
#        [ 180,   90,  577],
#        [ 180,  120,  496],
#        [ 180,  150,  337],
#        [ 180,  180,   38]])

# %%
Cartesian_coord_count = SphericalToCartesian(spherical_coord_count)

# %%
plot_df_count = pd.DataFrame(Cartesian_coord_count, columns = ['x','y','z'])
plot_df_count['longitude'] = result['longitude']
plot_df_count['lattitude'] = result['lattitude']
plot_df_count['count'] = result['r_count']

# %%
plot_df_count
# Out:
#                     x                  y                  z  longitude  \
# 0  -0.00000000000e+00 -0.00000000000e+00  4.60000000000e+01       -150
# 1  -1.21243556530e+02 -7.00000000000e+01  2.42487113060e+02       -150
# 2  -3.93750000000e+02 -2.27331668493e+02  2.62500000000e+02       -150
# 3  -5.62916512460e+02 -3.25000000000e+02  3.98010209723e-14       -150
# 4  -3.65250000000e+02 -2.10877185822e+02 -2.43500000000e+02       -150
# ..                ...                ...                ...        ...
# 79 -3.86247330088e+02  4.73016556471e-14  2.23000000000e+02        180
# 80 -5.77000000000e+02  7.06621203108e-14  3.53310601554e-14        180
# 81 -4.29548600277e+02  5.26045318408e-14 -2.48000000000e+02        180
# 82 -1.68500000000e+02  2.06352985656e-14 -2.91850561075e+02        180
# 83 -4.65365783676e-15  5.69908717412e-31 -3.80000000000e+01        180
#
#     lattitude  count
# 0           0     46
# 1          30    280
# 2          60    525
# 3          90    650
# 4         120    487
# ..        ...    ...
# 79         60    446
# 80         90    577
# 81        120    496
# 82        150    337
# 83        180     38
#
# [84 rows x 6 columns]

# %%
rows = plot_df_count.shape[0]


import plotly.graph_objects as go
import plotly.express as px
fig = go.Figure()

for i in range(rows):
    fig.add_trace(go.Scatter3d(x=[0, plot_df_count['x'][i]], y=[0, plot_df_count['y'][i]], z=[0, plot_df_count['z'][i]], mode='lines', 
                               line=dict(width=8),
                               name= f"Count: {plot_df_count['count'][i]}, lattitude: {plot_df_count['lattitude'][i]}, longitude: {plot_df_count['longitude'][i]}"))
 
fig.update_layout(
    title="Fabric plot: Number of contact forces in the defined directions",
    xaxis_title="X ",
    yaxis_title="Y",
    legend_title="Number of contact forces (count), direction",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="RebeccaPurple"
    )
)

fig.update_xaxes(tickfont_family='"PT Sans Narrow',tickfont_size = 1)

fig.show()
fig.write_html("fabric_plot_random_64_bi_count.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b0e714d8-42f7-4ad4-829b-dff39c3da76a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0e714d8-42f7-4ad4-829b-dff39c3da76a")) {                    Plotly.newPlot(                        "b0e714d8-42f7-4ad4-829b-dff39c3da76a",                        [{"line":{"width":8},"mode":"lines","name":"Count: 46, lattitude: 0, longitude: -150","x":[0,-0.0],"y":[0,-0.0],"z":[0,46.0],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 280, lattitude: 30, longitude: -150","x":[0,-121.2435565298214],"y":[0,-69.99999999999997],"z":[0,242.48711305964284],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 525, lattitude: 60, longitude: -150","x":[0,-393.75],"y":[0,-227.3316684934151],"z":[0,262.50000000000006],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 650, lattitude: 90, longitude: -150","x":[0,-562.9165124598852],"y":[0,-324.99999999999994],"z":[0,3.980102097228898e-14],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 487, lattitude: 120, longitude: -150","x":[0,-365.25000000000006],"y":[0,-210.8771858215108],"z":[0,-243.4999999999999],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 354, lattitude: 150, longitude: -150","x":[0,-153.28649646984562],"y":[0,-88.49999999999997],"z":[0,-306.5729929396913],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 38, lattitude: 180, longitude: -150","x":[0,-4.030185907154647e-15],"y":[0,-2.3268289183799706e-15],"z":[0,-38.0],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 50, lattitude: 0, longitude: -120","x":[0,-0.0],"y":[0,-0.0],"z":[0,50.0],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 384, lattitude: 30, longitude: -120","x":[0,-95.99999999999994],"y":[0,-166.2768775266122],"z":[0,332.55375505322445],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 539, lattitude: 60, longitude: -120","x":[0,-233.39384631990612],"y":[0,-404.25],"z":[0,269.50000000000006],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 664, lattitude: 90, longitude: -120","x":[0,-331.99999999999983],"y":[0,-575.0408681128673],"z":[0,4.0658273731692126e-14],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 571, lattitude: 120, longitude: -120","x":[0,-247.25025278045715],"y":[0,-428.25000000000006],"z":[0,-285.4999999999999],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 378, lattitude: 150, longitude: -120","x":[0,-94.49999999999994],"y":[0,-163.67880131525888],"z":[0,-327.3576026305178],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 45, lattitude: 180, longitude: -120","x":[0,-2.7554552980815436e-15],"y":[0,-4.772588574262081e-15],"z":[0,-45.0],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 45, lattitude: 0, longitude: -90","x":[0,0.0],"y":[0,-0.0],"z":[0,45.0],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 370, lattitude: 30, longitude: -90","x":[0,1.1327982892113015e-14],"y":[0,-184.99999999999997],"z":[0,320.42939940024235],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 549, lattitude: 60, longitude: -90","x":[0,2.9112790302998695e-14],"y":[0,-475.4479466776568],"z":[0,274.50000000000006],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 651, lattitude: 90, longitude: -90","x":[0,3.986225331224635e-14],"y":[0,-651.0],"z":[0,3.986225331224635e-14],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"Count: 562, lattitude: 120, longitude: -90","x":[0,2.980216420816989e-14],"y":[0,-486.70627692685457],"z":[0,-280.9999999999999],"type":"scatter3d"},{"line":{"width":8}," ...

# %% [markdown]
# Fabric plot(sum): This fabric plot adds the magnitude of force vectors in defined directions.

# %%
spherical_coord_sum = result[result.columns[:3]].to_numpy()
Cartesian_coord_sum = SphericalToCartesian(spherical_coord_sum)
plot_df = pd.DataFrame(Cartesian_coord_sum, columns = ['x','y','z'])
plot_df['longitude'] = result['longitude']
plot_df['lattitude'] = result['lattitude']
plot_df['force_sum'] = result['r_sum']
rows = plot_df.shape[0]


import plotly.graph_objects as go
import plotly.express as px
fig = go.Figure()

for i in range(rows):
    fig.add_trace(go.Scatter3d(x=[0, plot_df['x'][i]], y=[0, plot_df['y'][i]], z=[0, plot_df['z'][i]], mode='lines', 
                               line=dict(width=8),
                               name= f"lattitude: {plot_df['lattitude'][i]}, longitude: {plot_df['longitude'][i]}, force_sum: {round(plot_df['force_sum'][i], 3)}"))
    
fig.update_layout(
    title="Fabric plot: Force magnitude in defined directions",
    xaxis_title="X (N)",
    yaxis_title="Y (N)",
    legend_title="Sum of contact forces, direction",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="RebeccaPurple"
    )
)

fig.update_xaxes(tickfont_family='"PT Sans Narrow',tickfont_size = 1)
fig.show()
fig.write_html("fabric_plot_random_64_bi_sum.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="722b6299-7120-410c-8892-0444ddc30a0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("722b6299-7120-410c-8892-0444ddc30a0d")) {                    Plotly.newPlot(                        "722b6299-7120-410c-8892-0444ddc30a0d",                        [{"line":{"width":8},"mode":"lines","name":"lattitude: 0, longitude: -150, force_sum: 2.857","x":[0,-0.0],"y":[0,-0.0],"z":[0,2.856625863429716],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 30, longitude: -150, force_sum: 17.409","x":[0,-7.538131043423281],"y":[0,-4.352141987107104],"z":[0,15.076262086846564],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 60, longitude: -150, force_sum: 32.679","x":[0,-24.508894935276214],"y":[0,-14.150217088421973],"z":[0,16.339263290184146],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 90, longitude: -150, force_sum: 40.476","x":[0,-35.0529428054279],"y":[0,-20.237825964602347],"z":[0,2.4784188789251466e-15],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 120, longitude: -150, force_sum: 30.313","x":[0,-22.734862491588615],"y":[0,-13.12597897950781],"z":[0,-15.1565749943924],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 150, longitude: -150, force_sum: 22.011","x":[0,-9.53096342544648],"y":[0,-5.502704299318002],"z":[0,-19.061926850892963],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 180, longitude: -150, force_sum: 2.361","x":[0,-2.504292779138589e-16],"y":[0,-1.4458541101653002e-16],"z":[0,-2.361258954291083],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 0, longitude: -120, force_sum: 3.106","x":[0,-0.0],"y":[0,-0.0],"z":[0,3.1056677596039552],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 30, longitude: -120, force_sum: 23.862","x":[0,-5.965605616485606],"y":[0,-10.332732025671328],"z":[0,20.66546405134266],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 60, longitude: -120, force_sum: 33.507","x":[0,-14.508852619225362],"y":[0,-25.130069896027123],"z":[0,16.75337993068475],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 90, longitude: -120, force_sum: 41.288","x":[0,-20.64404343008105],"y":[0,-35.756532094558885],"z":[0,2.528166170810772e-15],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 120, longitude: -120, force_sum: 35.509","x":[0,-15.375960566546029],"y":[0,-26.631944916433277],"z":[0,-17.75462994428884],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 150, longitude: -120, force_sum: 23.494","x":[0,-5.87344536396479],"y":[0,-10.173105785866898],"z":[0,-20.3462115717338],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 180, longitude: -120, force_sum: 2.796","x":[0,-1.7118248743381457e-16],"y":[0,-2.964967656013879e-16],"z":[0,-2.7956221753569857],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 0, longitude: -90, force_sum: 2.796","x":[0,0.0],"y":[0,-0.0],"z":[0,2.7963323158216795],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 30, longitude: -90, force_sum: 22.995","x":[0,7.040042880522444e-16],"y":[0,-11.497262533857102],"z":[0,19.913842856598595],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 60, longitude: -90, force_sum: 34.117","x":[0,1.8091876715490256e-15],"y":[0,-29.546276898917345],"z":[0,17.058550921141155],"type":"scatter3d"},{"line":{"width":8},"mode":"lines","name":"lattitude: 90, longitude: -90, force_sum: 40.456","x":[0,2.4772258827588696e-15],"y":[0,-40.45616882326579],"z":[0,2.4772258827588696e-15],"type" ...

# %%
plot_df.describe()
# Out:
#                        x                  y                  z  \
# count  8.40000000000e+01  8.40000000000e+01  8.40000000000e+01
# mean   1.30767795192e-15  4.45044343960e-16  1.68119486586e-15
# std    1.52882775160e+01  1.62224538948e+01  1.34031256872e+01
# min   -3.59500446199e+01 -4.04561688233e+01 -2.06654640513e+01
# 25%   -6.35873697322e+00 -6.32611497748e+00 -1.52284275140e+01
# 50%    8.62227839729e-33  0.00000000000e+00  2.47782238084e-15
# 75%    6.35873697322e+00  6.32611497748e+00  1.52284275140e+01
# max    3.59500446199e+01  4.04561688233e+01  2.06654640513e+01
#
#              longitude        lattitude       force_sum
# count   84.00000000000   84.00000000000  84.00000000000
# mean    15.00000000000   90.00000000000  21.84331603060
# std    104.18357292525   60.36036360043  13.91632864830
# min   -150.00000000000    0.00000000000   1.67769353231
# 25%    -67.50000000000   30.00000000000   2.91986662838
# 50%     15.00000000000   90.00000000000  22.84173213821
# 75%     97.50000000000  150.00000000000  34.56197658191
# max    180.00000000000  180.00000000000  41.28808686016

# %%
plot_df
# Out:
#                     x                  y                  z  longitude  \
# 0  -0.00000000000e+00 -0.00000000000e+00  2.85662586343e+00       -150
# 1  -7.53813104342e+00 -4.35214198711e+00  1.50762620868e+01       -150
# 2  -2.45088949353e+01 -1.41502170884e+01  1.63392632902e+01       -150
# 3  -3.50529428054e+01 -2.02378259646e+01  2.47841887893e-15       -150
# 4  -2.27348624916e+01 -1.31259789795e+01 -1.51565749944e+01       -150
# ..                ...                ...                ...        ...
# 79 -2.40466807218e+01  2.94486905760e-15  1.38833575878e+01        180
# 80 -3.59500446199e+01  4.40261070729e-15  2.20130535365e-15        180
# 81 -2.67497668175e+01  3.27590163109e-15 -1.54439850728e+01        180
# 82 -1.04805983633e+01  1.28350312388e-15 -1.81529288590e+01        180
# 83 -2.89176081347e-16  3.54138562412e-32 -2.36130189985e+00        180
#
#     lattitude       force_sum
# 0           0   2.85662586343
# 1          30  17.40856794843
# 2          60  32.67852658037
# 3          90  40.47565192920
# 4         120  30.31314998878
# ..        ...             ...
# 79         60  27.76671517567
# 80         90  35.95004461986
# 81        120  30.88797014563
# 82        150  20.96119672669
# 83        180   2.36130189985
#
# [84 rows x 6 columns]
